# %%
import numpy as np
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, RobertaForQuestionAnswering
import torch, json, os

tokenizer = AutoTokenizer.from_pretrained("deepset/roberta-base-squad2")
model = RobertaForQuestionAnswering.from_pretrained("deepset/roberta-base-squad2")
sentence_model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# %%
data = []
folder_name = "crisisfacts_008"
path = f"/Users/yash/Documents/GitHub/Code-Maroon-Global-Edition/Test_Data/data/{folder_name}"
doc_count = 0
for file in os.listdir(path):
    # if doc_count == 5:
    #     break
    # doc_count += 1
    with open(f"{path}/{file}", 'r') as f:
        json_str = f.read()

    # Split the string into individual JSON objects
    json_objs = json_str.strip().split('}{')

    # Add back the missing braces to each object
    for i in range(len(json_objs)):
        if i == 0:
            json_objs[i] += '}'
        elif i == len(json_objs) - 1:
            json_objs[i] = '{' + json_objs[i]
        else:
            json_objs[i] = '{' + json_objs[i] + '}'

    
    for json_obj in json_objs:
        try:
            text_val = json.loads(json_obj)
            if text_val["source_type"] == "News":
                data.append(text_val) 
        except:
            continue

# %%
text_lines = []
for i in range(len(data)):
    if data[i]['source_type'] == "News" and "heading" in data[i]:
        text_lines.append(data[i]['heading']) 

# Embed each line in text_lines
text_lines_embeddings = []

# Encode the text_lines list
text_lines_embeddings = sentence_model.encode(text_lines)

embedding_dict = dict(zip(text_lines, text_lines_embeddings))

# %%
def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def compute_exact_match(prediction, truth):
    return int(normalize_text(prediction) == normalize_text(truth))

def get_gold_answers(example):
    """helper function that retrieves all possible true answers from a squad2.0 example"""
    
    # gold_answers = [answer["text"] for answer in example.answers if answer["text"]]
    gold_answers = [answer for answer in example['answers'] if answer]

    # if gold_answers doesn't exist it's because this is a negative example - 
    # the only correct answer is an empty string
    if not gold_answers:
        gold_answers = [""]
        
    return gold_answers

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()
    
    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens), 0, 0
    
    common_tokens = set(pred_tokens) & set(truth_tokens)
    
    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0, 0, 0
    
    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)
    
    return 2 * (prec * rec) / (prec + rec) , prec, rec

def get_question_context(question_embeddings):
    cosine_values = []
    for text in embedding_dict:
        value = np.dot(question_embeddings, np.array(embedding_dict[text]))
        cosine_values.append({"text": text, "value": value})

    sorted_cosine_values = sorted(cosine_values, key=lambda x: x['value'], reverse=True)

    # Get context string
    context = ""
    counter = 0
    for val in sorted_cosine_values:
        context += val['text'] + "\n"
        counter += 1
        if counter == 15:
            break
    return context

def get_answers(question, context):
    inputs = tokenizer(question, context, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)

    answer_start_index = outputs.start_logits.argmax()
    answer_end_index = outputs.end_logits.argmax()

    predict_answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
    answer = tokenizer.decode(predict_answer_tokens, skip_special_tokens=True)
    return answer

# %%
test_queries =  [
        {
        "question": "What was the name of the hurricane that made landfall in Alabama and Mississippi on September 16, 2020?",
        "answers": ["Hurricane Sally"]
        },
        
        {
        "question": "What was the maximum sustained wind speed of Hurricane Sally when it made landfall?",
        "answers": ["105 mph", "100 mph", "40 mph", "90 mph"]
        },
        
        {
        "question": "Where did Hurricane Sally make landfall in Alabama?",
        "answers": ["Gulf Shores"]
        },
        
        {
        "question": "Where did Hurricane Sally make landfall in Mississippi?",
        "answers": ["Bay St. Louis"]
        },
        
        {
        "question": "What was the total damage caused by Hurricane Sally?",
        "answers": ["More than $3 billion"]
        },
        
        {
        "question": "How many deaths were caused by Hurricane Sally?",
        "answers": ["At least 3"]
        },
        
        {
        "question": "What were the main impacts of Hurricane Sally?",
        "answers": ["Flooding", "Power outages", "Structural damage"]
        },
        
        {
        "question": "What was the weather like in the days leading up to Hurricane Sally?",
        "answers": ["Warm and humid"]
        },
        
        {
        "question": "What was the weather like in the days after Hurricane Sally?",
        "answers": ["Cool and rainy"]
        },
        
        {
        "question": "What were the evacuation orders for Hurricane Sally?",
        "answers": ["Mandatory evacuations for some areas"]
        },
        
        {
        "question": "What were the shelter options for Hurricane Sally?",
        "answers": ["Public shelters", "Private shelters", "Staying with friends or family"]
        },
        
        {
        "question": "What were the transportation options for Hurricane Sally?",
        "answers": ["Closed roads", "Cancelled flights", "Limited public transportation"]
        },
        
        {
        "question": "What were the communication options for Hurricane Sally?",
        "answers": ["Cell phone service was spotty", "Power outages affected landlines", "Radios were a good source of information"]
        }
    ]

# %%
test_queries_facts =  [
        {
        "question": "How much rain is measured in Pensacola, Florida as of Tuesday?",
        "answers": ["12.71 inches"]
        },
        
        {
        "question": "Which areas are expecting heavy rain along I-10 highway from Louisiana to Florida,",
        "answers": [" Gautier and Pascagoula, Mississippi","Gautier","Pascagoula, Mississippi"]
        },
        
        {
        "question": "What is the contact number to report downed power lines?",
        "answers": ["1-800-GUPOWER","1-800-487-6937","1-800-GUPOWER (1-800-487-6937)"]
        },
        
        {
        "question": "How many meal red cross has served?",
        "answers": ["622,000"]
        },
        
        {
        "question": "What is the contact number of Alabama Power?",
        "answers": ["1-800-888-2726"]
        }
    ]

# %% [markdown]
# # RoBERTa: A Robustly Optimized BERT Pretraining Approach EVALUATION

# %%
# Roberta Squad Evaluation
f1_scores = []
em_scores = []
recall_scores = []
precision_scores = []
for query in test_queries:
    question = query['question']
    question_embeddings = sentence_model.encode([question])[0]

    context = get_question_context(question_embeddings)
    predicted_answer = get_answers(question, context)

    # print("Context: ", context)
    print("Question: ", question)
    print("Answer: ", predicted_answer)

    gold_answers = get_gold_answers(query)

    em_score = max((compute_exact_match(answer, predicted_answer)) for answer in gold_answers)
    # f1_score , prec, rec  = max((compute_f1(answer, predicted_answer)) for answer in gold_answers)
    f1_list = []
    prec_list = []
    rec_list = []
    for answer in gold_answers:
        f1_score , prec, rec = compute_f1(answer, predicted_answer)
        f1_list.append(f1_score)
        prec_list.append(prec)
        rec_list.append(rec)

    # print(f"Question: {query['question']}")
    # print(f"Prediction: {predicted_answer}")
    print(f"True Answers: {gold_answers}")
    print(f"EM: {em_score} \t F1: {f1_score}")
    print(f"Precision: {max(prec_list)} \t Recall: {max(rec_list)}")

    em_scores.append(em_score)
    f1_scores.append(f1_score)
    recall_scores.append(max(rec_list))
    precision_scores.append(max(prec_list))

print(f"Average Exact Match: {(sum(em_scores) * 100 )/len(em_scores)} %")    
print(f"Average F1 score: {sum(f1_scores)/len(f1_scores)}")    
print(f"Average Recall: {(sum(recall_scores) * 100)/len(recall_scores)} %")    
print(f"Average Precision: {(sum(precision_scores) * 100) /len(precision_scores)} %")
# Out:
# Question:  What was the name of the hurricane that made landfall in Alabama and Mississippi on September 16, 2020?
# Answer:  What was the name of the hurricane that made landfall in Alabama and Mississippi on September 16, 2020?Landfall is forecast to occur Wednesday morning near the Mississippi/Alabama state line.
# Landfall is likely along the Louisiana or Mississippi coast.
# Hurricane Watch from Southeast Louisiana through Alabama
# A hurricane warning is in effect for the Mississippi/Alabama border.
# Hurricane Warning Issued For the Coast of Alabama.
# Hurricane Sally
# True Answers: ['Hurricane Sally']
# EM: 0 	 F1: 0.06666666666666667
# Precision: 1.0 	 Recall: 0.034482758620689655
# Question:  What was the maximum sustained wind speed of Hurricane Sally when it made landfall?
# Answer:   90 mph
# True Answers: ['105 mph', '100 mph', '40 mph', '90 mph']
# EM: 1 	 F1: 1.0
# Precision: 1.0 	 Recall: 1.0
# Question:  Where did Hurricane Sally make landfall in Alabama?
# Answer:   Gulf Shores, Alabama
# True Answers: ['Gulf Shores']
# EM: 0 	 F1: 0.8
# Precision: 1.0 	 Recall: 0.6666666666666666
# Question:  Where did Hurricane Sally make landfall in Mississippi?
# Answer:
# True Answers: ['Bay St. Louis']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What was the total damage caused by Hurricane Sally?
# Answer:  severe widespread damage
# True Answers: ['More than $3 billion']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  How many deaths were caused by Hurricane Sally?
# Answer:
# True Answers: ['At least 3']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What were the main impacts of Hurricane Sally?
# Answer:   inland flooding and storm surge
# True Answers: ['Flooding', 'Power outages', 'Structural damage']
# EM: 0 	 F1: 0
# Precision: 1.0 	 Recall: 0.2
# Question:  What was the weather like in the days leading up to Hurricane Sally?
# Answer:
# True Answers: ['Warm and humid']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What was the weather like in the days after Hurricane Sally?
# Answer:
# True Answers: ['Cool and rainy']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What were the evacuation orders for Hurricane Sally?
# Answer:   mandatory evacuation orders
# True Answers: ['Mandatory evacuations for some areas']
# EM: 0 	 F1: 0.25
# Precision: 0.2 	 Recall: 0.3333333333333333
# Question:  What were the shelter options for Hurricane Sally?
# Answer:
# True Answers: ['Public shelters', 'Private shelters', 'Staying with friends or family']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What were the transportation options for Hurricane Sally?
# Answer:  What were the transportation options for Hurricane Sally?It was also making preparations for Hurricane Sally.
# Hurricane Sally: What you can expect in the Wilmington area
# ‘The scariest adventure:’ Riding out Hurricane Sally
# PHOTOS: Scenes from Hurricane Sally in Northwest Florida
# All of Louisiana in cone for predicted Hurricane Sally
# After Hurricane Sally, rescue, recovery and a wary eye on rivers
# How climate change may be making Hurricane Sally worse
# For the latest on preparations for Hurricane Sally, click here.
# PHOTOS: Hurricane Sally damage and flooding in Northwest Florida
# Hurricane Sally’s threat: ‘Potentially historic’ floods, fierce winds
# Destin's charter boats
# True Answers: ['Closed roads', 'Cancelled flights', 'Limited public transportation']
# EM: 0 	 F1: 0.020408163265306124
# Precision: 0.3333333333333333 	 Recall: 0.010526315789473684
# Question:  What were the communication options for Hurricane Sally?
# Answer:
# True Answers: ['Cell phone service was spotty', 'Power outages affected landlines', 'Radios were a good source of information']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Average Exact Match: 7.6923076923076925 %
# Average F1 score: 0.16439037153322866
# Average Recall: 17.269300572385873 %
# Average Precision: 34.87179487179487 %

# %% [markdown]
# # OPEN AI TESTING

# %%
# %pip install openai
import openai
openai.api_key = "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"
model_engine = "text-davinci-003"
# model_engine = "curie-002"

# %%
def get_openai_answers(question, context):
    prompt_template = "Question: {question}\nContext: {context}\nAnswer:"

    prompt = prompt_template.format(question=question, context=context)
    response = openai.Completion.create(
                engine=model_engine,
        #   prompt=prompt, max_tokens=1024, n=1,
          # prompt=prompt, max_tokens=20, n=1,
          prompt=prompt, max_tokens=100, n=1,
            stop=None,
            # stop=" ",
            # temperature=0.5,
            temperature=0.3,
        )
    answer = response.choices[0].text.strip()
    return answer

# %%
# Open AI Evaluation
f1_scores = []
em_scores = []
recall_scores = []
precision_scores = []
for query in test_queries:
    question = query['question']
    question_embeddings = sentence_model.encode([question])[0]

    context = get_question_context(question_embeddings)
    predicted_answer = get_openai_answers(question, context)

    # print("Context: ", context)
    print("Question: ", question)
    print("Answer: ", predicted_answer)

    gold_answers = get_gold_answers(query)

    em_score = max((compute_exact_match(answer, predicted_answer)) for answer in gold_answers)
    # f1_score , prec, rec  = max((compute_f1(answer, predicted_answer)) for answer in gold_answers)
    f1_list = []
    prec_list = []
    rec_list = []
    for answer in gold_answers:
        f1_score , prec, rec = compute_f1(answer, predicted_answer)
        f1_list.append(f1_score)
        prec_list.append(prec)
        rec_list.append(rec)

    # print(f"Question: {query['question']}")
    # print(f"Prediction: {predicted_answer}")
    print(f"True Answers: {gold_answers}")
    print(f"EM: {em_score} \t F1: {f1_score}")
    print(f"Precision: {max(prec_list)} \t Recall: {max(rec_list)}")

    em_scores.append(em_score)
    f1_scores.append(f1_score)
    recall_scores.append(max(rec_list))
    precision_scores.append(max(prec_list))

print(f"Average Exact Match: {(sum(em_scores) * 100 )/len(em_scores)} %")    
print(f"Average F1 score: {sum(f1_scores)/len(f1_scores)}")    
print(f"Average Recall: {(sum(recall_scores) * 100)/len(recall_scores)} %")    
print(f"Average Precision: {(sum(precision_scores) * 100) /len(precision_scores)} %")
# Out:
# Question:  What was the name of the hurricane that made landfall in Alabama and Mississippi on September 16, 2020?
# Answer:  Hurricane Sally
# True Answers: ['Hurricane Sally']
# EM: 1 	 F1: 1.0
# Precision: 1.0 	 Recall: 1.0
# Question:  What was the maximum sustained wind speed of Hurricane Sally when it made landfall?
# Answer:  The maximum sustained wind speed of Hurricane Sally when it made landfall was 105 mph.
# True Answers: ['105 mph', '100 mph', '40 mph', '90 mph']
# EM: 0 	 F1: 0.125
# Precision: 1.0 	 Recall: 0.14285714285714285
# Question:  Where did Hurricane Sally make landfall in Alabama?
# Answer:  Hurricane Sally made landfall near Gulf Shores, Alabama.
# True Answers: ['Gulf Shores']
# EM: 0 	 F1: 0.4
# Precision: 1.0 	 Recall: 0.25
# Question:  Where did Hurricane Sally make landfall in Mississippi?
# Answer:  Sally made landfall near the Louisiana-Mississippi border.
# True Answers: ['Bay St. Louis']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What was the total damage caused by Hurricane Sally?
# Answer:  The total damage caused by Hurricane Sally is not yet known, as the storm is still ongoing and the full extent of the damage is still being assessed.
# True Answers: ['More than $3 billion']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  How many deaths were caused by Hurricane Sally?
# Answer:  At least one death has been reported as a result of Hurricane Sally.
# True Answers: ['At least 3']
# EM: 0 	 F1: 0.26666666666666666
# Precision: 0.6666666666666666 	 Recall: 0.16666666666666666
# Question:  What were the main impacts of Hurricane Sally?
# Answer:  The main impacts of Hurricane Sally were catastrophic damage, severe widespread damage, inland flooding, storm surge, and damage to the Alabama Gulf Coast. It also had the potential to cause weather impacts in Louisiana.
# True Answers: ['Flooding', 'Power outages', 'Structural damage']
# EM: 0 	 F1: 0.06060606060606061
# Precision: 1.0 	 Recall: 0.03225806451612903
# Question:  What was the weather like in the days leading up to Hurricane Sally?
# Answer:  The weather in the days leading up to Hurricane Sally was generally clear and warm, with temperatures in the mid-80s and low-90s. There were some scattered showers and thunderstorms, but overall the weather was mild and pleasant.
# True Answers: ['Warm and humid']
# EM: 0 	 F1: 0.1111111111111111
# Precision: 0.6666666666666666 	 Recall: 0.06060606060606061
# Question:  What was the weather like in the days after Hurricane Sally?
# Answer:  In the days after Hurricane Sally, the weather was generally clear and cooler, with some areas experiencing rainfall due to the storm.
# True Answers: ['Cool and rainy']
# EM: 0 	 F1: 0.09090909090909091
# Precision: 0.3333333333333333 	 Recall: 0.05263157894736842
# Question:  What were the evacuation orders for Hurricane Sally?
# Answer:  The evacuation orders for Hurricane Sally in Louisiana and Mississippi included mandatory evacuations for all of Louisiana and voluntary evacuations for Zone A in Escambia County.
# True Answers: ['Mandatory evacuations for some areas']
# EM: 0 	 F1: 0.20689655172413793
# Precision: 0.6 	 Recall: 0.125
# Question:  What were the shelter options for Hurricane Sally?
# Answer:  Shelter options for Hurricane Sally included Montgomery livestock shelter, shelters in Mississippi, and all of Louisiana.
# True Answers: ['Public shelters', 'Private shelters', 'Staying with friends or family']
# EM: 0 	 F1: 0
# Precision: 0.5 	 Recall: 0.0625
# Question:  What were the transportation options for Hurricane Sally?
# Answer:  During Hurricane Sally, people in the affected areas had a few transportation options. These included riding out the storm in a charter boat, driving out of the area if possible, and using public transportation if available. Additionally, some states took steps to prepare for the hurricane by providing extra transportation options, such as providing extra buses or shuttles to help evacuate people.
# True Answers: ['Closed roads', 'Cancelled flights', 'Limited public transportation']
# EM: 0 	 F1: 0.06779661016949153
# Precision: 0.6666666666666666 	 Recall: 0.03571428571428571
# Question:  What were the communication options for Hurricane Sally?
# Answer:  The communication options for Hurricane Sally included the following: photos, steps taken to prepare, storm tracker updates, climate change impacts, the latest preparations, updates from the State of Florida, and photos of the damage and flooding.
# True Answers: ['Cell phone service was spotty', 'Power outages affected landlines', 'Radios were a good source of information']
# EM: 0 	 F1: 0.05405405405405405
# Precision: 0.16666666666666666 	 Recall: 0.03225806451612903
# Average Exact Match: 7.6923076923076925 %
# Average F1 score: 0.183310780403124
# Average Recall: 15.080706644798324 %
# Average Precision: 58.46153846153846 %

# %% [markdown]
# # FLAN T5 Evaluation

# %%
# %pip install chromadb langchain
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain import HuggingFaceHub
from langchain.document_loaders import TextLoader
from langchain.embeddings import HuggingFaceEmbeddings
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
llm = HuggingFaceHub(repo_id="google/flan-t5-small", model_kwargs={"temperature":0, "max_length": 64})
embeddings = HuggingFaceEmbeddings()

# %%
# Load context file with heading
with open("context.txt", "w+") as fd:
    fd.write(".\n\n".join(text_lines))

# %%
# It takes all heading data and then store embeddings in chroma DB as initialize qa model for finding answer of query
loader = TextLoader("context.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(separator=".\n\n",chunk_size=10,chunk_overlap=0,
# text_splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=30,
    length_function = len)
texts = text_splitter.split_documents(documents)
print(texts)
print(len(texts))
docsearch = Chroma.from_documents(texts, embeddings)
# Out:
# Created a chunk of size 105, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 72, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 178, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 150, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 116, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 177, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 175, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 128, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 181, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 58, which is longer than the specified 10
# Created a chunk of size 148, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 145, which is longer than the specified 10
# Created a chunk of size 88, which is longer than the specified 10
# Created a chunk of size 180, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 137, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 161, which is longer than the specified 10
# Created a chunk of size 132, which is longer than the specified 10
# Created a chunk of size 132, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 92, which is longer than the specified 10
# Created a chunk of size 198, which is longer than the specified 10
# Created a chunk of size 156, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 91, which is longer than the specified 10
# Created a chunk of size 85, which is longer than the specified 10
# Created a chunk of size 195, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 123, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 133, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 124, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 61, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 142, which is longer than the specified 10
# Created a chunk of size 142, which is longer than the specified 10
# Created a chunk of size 82, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 131, which is longer than the specified 10
# Created a chunk of size 123, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 180, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 75, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 80, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 167, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 57, which is longer than the specified 10
# Created a chunk of size 123, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 152, which is longer than the specified 10
# Created a chunk of size 86, which is longer than the specified 10
# Created a chunk of size 106, which is longer than the specified 10
# Created a chunk of size 89, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 71, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 133, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 55, which is longer than the specified 10
# Created a chunk of size 92, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 82, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 159, which is longer than the specified 10
# Created a chunk of size 57, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 166, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 131, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 154, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 175, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 166, which is longer than the specified 10
# Created a chunk of size 121, which is longer than the specified 10
# Created a chunk of size 62, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 173, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 68, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 104, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 105, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 91, which is longer than the specified 10
# Created a chunk of size 182, which is longer than the specified 10
# Created a chunk of size 188, which is longer than the specified 10
# Created a chunk of size 151, which is longer than the specified 10
# Created a chunk of size 121, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 91, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 185, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 65, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 157, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 182, which is longer than the specified 10
# Created a chunk of size 62, which is longer than the specified 10
# Created a chunk of size 65, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 151, which is longer than the specified 10
# Created a chunk of size 182, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 61, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 139, which is longer than the specified 10
# Created a chunk of size 82, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 150, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 177, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 76, which is longer than the specified 10
# Created a chunk of size 145, which is longer than the specified 10
# Created a chunk of size 52, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 68, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 139, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 173, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 68, which is longer than the specified 10
# Created a chunk of size 77, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 78, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 89, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 164, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 70, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 53, which is longer than the specified 10
# Created a chunk of size 164, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 150, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 69, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 53, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 123, which is longer than the specified 10
# Created a chunk of size 152, which is longer than the specified 10
# Created a chunk of size 153, which is longer than the specified 10
# Created a chunk of size 76, which is longer than the specified 10
# Created a chunk of size 129, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 159, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 135, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 53, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 108, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 180, which is longer than the specified 10
# Created a chunk of size 117, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 121, which is longer than the specified 10
# Created a chunk of size 156, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 80, which is longer than the specified 10
# Created a chunk of size 104, which is longer than the specified 10
# Created a chunk of size 116, which is longer than the specified 10
# Created a chunk of size 164, which is longer than the specified 10
# Created a chunk of size 83, which is longer than the specified 10
# Created a chunk of size 128, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 133, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 70, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 86, which is longer than the specified 10
# Created a chunk of size 114, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 75, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 137, which is longer than the specified 10
# Created a chunk of size 150, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 144, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 178, which is longer than the specified 10
# Created a chunk of size 183, which is longer than the specified 10
# Created a chunk of size 88, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 135, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 139, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 62, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 76, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 52, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 83, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 104, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 89, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 78, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 148, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 104, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 70, which is longer than the specified 10
# Created a chunk of size 85, which is longer than the specified 10
# Created a chunk of size 53, which is longer than the specified 10
# Created a chunk of size 106, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 145, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 88, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 56, which is longer than the specified 10
# Created a chunk of size 86, which is longer than the specified 10
# Created a chunk of size 54, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 57, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 132, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 185, which is longer than the specified 10
# Created a chunk of size 172, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 153, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 195, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 150, which is longer than the specified 10
# Created a chunk of size 151, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 161, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 91, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 135, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 174, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 177, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 145, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 91, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 106, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 82, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 56, which is longer than the specified 10
# Created a chunk of size 78, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 80, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 184, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 121, which is longer than the specified 10
# Created a chunk of size 131, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 88, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 124, which is longer than the specified 10
# Created a chunk of size 57, which is longer than the specified 10
# Created a chunk of size 164, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 121, which is longer than the specified 10
# Created a chunk of size 71, which is longer than the specified 10
# Created a chunk of size 179, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 167, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 105, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 75, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 193, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 164, which is longer than the specified 10
# Created a chunk of size 149, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 72, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 170, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 117, which is longer than the specified 10
# Created a chunk of size 144, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 54, which is longer than the specified 10
# Created a chunk of size 163, which is longer than the specified 10
# Created a chunk of size 193, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 76, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 149, which is longer than the specified 10
# Created a chunk of size 155, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 163, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 170, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 195, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 159, which is longer than the specified 10
# Created a chunk of size 164, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 56, which is longer than the specified 10
# Created a chunk of size 174, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 106, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 149, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 129, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 54, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 151, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 104, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 135, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 186, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 150, which is longer than the specified 10
# Created a chunk of size 163, which is longer than the specified 10
# Created a chunk of size 70, which is longer than the specified 10
# Created a chunk of size 104, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 62, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 69, which is longer than the specified 10
# Created a chunk of size 153, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 154, which is longer than the specified 10
# Created a chunk of size 172, which is longer than the specified 10
# Created a chunk of size 115, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 121, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 171, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 158, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 78, which is longer than the specified 10
# Created a chunk of size 195, which is longer than the specified 10
# Created a chunk of size 184, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 133, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 53, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 131, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 151, which is longer than the specified 10
# Created a chunk of size 155, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 142, which is longer than the specified 10
# Created a chunk of size 92, which is longer than the specified 10
# Created a chunk of size 65, which is longer than the specified 10
# Created a chunk of size 76, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 56, which is longer than the specified 10
# Created a chunk of size 123, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 156, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 144, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 92, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 131, which is longer than the specified 10
# Created a chunk of size 75, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 124, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 195, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 78, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 177, which is longer than the specified 10
# Created a chunk of size 117, which is longer than the specified 10
# Created a chunk of size 161, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 56, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# ...
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 148, which is longer than the specified 10
# Created a chunk of size 133, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 83, which is longer than the specified 10
# Created a chunk of size 115, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 76, which is longer than the specified 10
# Created a chunk of size 86, which is longer than the specified 10
# Created a chunk of size 77, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 158, which is longer than the specified 10
# Created a chunk of size 193, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 61, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 163, which is longer than the specified 10
# Created a chunk of size 89, which is longer than the specified 10
# Created a chunk of size 132, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 143, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 71, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 117, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 57, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 61, which is longer than the specified 10
# Created a chunk of size 54, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 68, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 86, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 128, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 103, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 128, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 86, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 105, which is longer than the specified 10
# Created a chunk of size 62, which is longer than the specified 10
# Created a chunk of size 128, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 144, which is longer than the specified 10
# Created a chunk of size 147, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 74, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 72, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 108, which is longer than the specified 10
# Created a chunk of size 82, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 75, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 76, which is longer than the specified 10
# Created a chunk of size 62, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 68, which is longer than the specified 10
# Created a chunk of size 181, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 56, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 50, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 80, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 152, which is longer than the specified 10
# Created a chunk of size 129, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 89, which is longer than the specified 10
# Created a chunk of size 159, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 61, which is longer than the specified 10
# Created a chunk of size 178, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 65, which is longer than the specified 10
# Created a chunk of size 83, which is longer than the specified 10
# Created a chunk of size 179, which is longer than the specified 10
# Created a chunk of size 115, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 75, which is longer than the specified 10
# Created a chunk of size 68, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 145, which is longer than the specified 10
# Created a chunk of size 167, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 135, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 82, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 53, which is longer than the specified 10
# Created a chunk of size 67, which is longer than the specified 10
# Created a chunk of size 72, which is longer than the specified 10
# Created a chunk of size 173, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 80, which is longer than the specified 10
# Created a chunk of size 185, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 149, which is longer than the specified 10
# Created a chunk of size 72, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 61, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 70, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 51, which is longer than the specified 10
# Created a chunk of size 63, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 120, which is longer than the specified 10
# Created a chunk of size 95, which is longer than the specified 10
# Created a chunk of size 121, which is longer than the specified 10
# Created a chunk of size 57, which is longer than the specified 10
# Created a chunk of size 152, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 168, which is longer than the specified 10
# Using embedded DuckDB without persistence: data will be transient
# [Document(page_content='Hurricane Sally Slowly Creeping Toward Gulf Coast With Potentially Historic and Life-Threatening Flooding', metadata={'source': 'context.txt'}), Document(page_content='At a Glance Hurricane Sally is moving very slowly in the northern Gulf of Mexico.', metadata={'source': 'context.txt'}), Document(page_content="Sally's slow movement will result in prolonged impacts on the Gulf Coast.", metadata={'source': 'context.txt'}), Document(page_content='Life-threatening storm surge is expected, particularly in parts of Alabama and the western Florida Panhandle.', metadata={'source': 'context.txt'}), Document(page_content='Flooding rain is a major threat from Sally on the Gulf Coast and farther inland across the Southeast this week.', metadata={'source': 'context.txt'}), Document(page_content='Rainfall totals of up to 30 inches could result in historic flooding near and just inland from the northern Gulf Coast.', metadata={'source': 'context.txt'}), Document(page_content="Damaging winds are expected near where Sally's center crosses the coast.", metadata={'source': 'context.txt'}), Document(page_content='Hurricane Sally is moving very slowly toward the northern Gulf Coast, where it will bring potentially historic flooding rainfall, a dangerous storm surge and damaging winds through Wednesday.', metadata={'source': 'context.txt'}), Document(page_content='Sally will also pose a threat of flooding rainfall farther inland across parts of the Southeast.', metadata={'source': 'context.txt'}), Document(page_content='Flooding, power outages and bridge closures have already spread throughout coastal Alabama and northwestern Florida and dangerous conditions will persist through Wednesday there.', metadata={'source': 'context.txt'}), Document(page_content='(LATEST: Power Outages and Flooding Spread as Sally Batters Gulf Coast)  Current Alerts  A hurricane warning has been issued from east of Bay St. Louis, Mississippi, to the Okaloosa/Walton County line', metadata={'source': 'context.txt'}), Document(page_content='Hurricane conditions (winds 74 mph or greater) are expected in some parts of this area into Wednesday.', metadata={'source': 'context.txt'}), Document(page_content='Tropical storm warnings are in effect to west and east of this hurricane warning, including portions of southeast Louisiana and the Florida Panhandle.', metadata={'source': 'context.txt'}), Document(page_content='A storm surge warning is also in effect from the mouth of the Mississippi River in Louisiana to the mouth of the Pearl River, as well as from the Mississippi/Alabama border to the Walton/Bay County li', metadata={'source': 'context.txt'}), Document(page_content='This means there will be a danger of life-threatening inundation from storm surge within the warning area in the next 36 hours.', metadata={'source': 'context.txt'}), Document(page_content='Current Wind Watches and Warnings  Happening Now  Sally is centered south-southeast of Mobile, Alabama.', metadata={'source': 'context.txt'}), Document(page_content='Some additional strengthening of Sally is possible before landfall.', metadata={'source': 'context.txt'}), Document(page_content='Hurricane-force winds extend outward up to 40 miles and tropical-storm-force winds extend outward up to 125 miles from the center of the storm.', metadata={'source': 'context.txt'}), Document(page_content="Current Wind Field (The orange circle shows the extent of the system's tropical-storm-force winds (at least 39 mph).", metadata={'source': 'context.txt'}), Document(page_content='The purple circle indicates the extent of hurricane-force winds (at least 74 mph), according to the National Hurricane Center.)', metadata={'source': 'context.txt'}), Document(page_content='Bands of heavy rain and strong winds are affecting the northern Gulf Coast right now, particularly in parts of the Florida Panhandle, southern Alabama and southeast Mississippi.', metadata={'source': 'context.txt'}), Document(page_content='On Tue ...
# 11787

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch.as_retriever(search_kwargs={"k": 50}))

# %%
# Loop through all queries and perform evaluation
f1_scores = []
em_scores = []
recall_scores = []
precision_scores = []
for query in test_queries:
    question = query['question']

    # Answer string (CHECK BY YASH) get output string
    predicted_answer = qa.run(question) 

    # Get gold answers
    gold_answers = get_gold_answers(query)

    # get EM score
    em_score = max((compute_exact_match(answer, predicted_answer)) for answer in gold_answers)
    # f1_score , prec, rec  = max((compute_f1(answer, predicted_answer)) for answer in gold_answers)
    
    # Get prec, rec and f1
    f1_list = []
    prec_list = []
    rec_list = []
    for answer in gold_answers:
        f1_score , prec, rec = compute_f1(answer, predicted_answer)
        f1_list.append(f1_score)
        prec_list.append(prec)
        rec_list.append(rec)

    print("Question: ", question)
    print("Answer: ", predicted_answer)
    print(f"True Answers: {gold_answers}")
    print(f"EM: {em_score} \t F1: {f1_score}")
    print(f"Precision: {max(prec_list)} \t Recall: {max(rec_list)}")

    em_scores.append(em_score)
    f1_scores.append(f1_score)
    recall_scores.append(max(rec_list))
    precision_scores.append(max(prec_list))

print(f"Average Exact Match: {(sum(em_scores) * 100 )/len(em_scores)} %")    
print(f"Average F1 score: {sum(f1_scores)/len(f1_scores)}")    
print(f"Average Recall: {(sum(recall_scores) * 100)/len(recall_scores)} %")    
print(f"Average Precision: {(sum(precision_scores) * 100) /len(precision_scores)} %")
# Out:
# Question:  What was the name of the hurricane that made landfall in Alabama and Mississippi on September 16, 2020?
# Answer:  Hurricane Sally
# True Answers: ['Hurricane Sally']
# EM: 1 	 F1: 1.0
# Precision: 1.0 	 Recall: 1.0
# Question:  What was the maximum sustained wind speed of Hurricane Sally when it made landfall?
# Answer:  105 mph
# True Answers: ['105 mph', '100 mph', '40 mph', '90 mph']
# EM: 1 	 F1: 0.5
# Precision: 1.0 	 Recall: 1.0
# Question:  Where did Hurricane Sally make landfall in Alabama?
# Answer:  Gulf Shores, Alabama
# True Answers: ['Gulf Shores']
# EM: 0 	 F1: 0.8
# Precision: 1.0 	 Recall: 0.6666666666666666
# Question:  Where did Hurricane Sally make landfall in Mississippi?
# Answer:  Gulf Shores, Alabama
# True Answers: ['Bay St. Louis']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What was the total damage caused by Hurricane Sally?
# Answer:  a).
# True Answers: ['More than $3 billion']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  How many deaths were caused by Hurricane Sally?
# Answer:  1).
# True Answers: ['At least 3']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What were the main impacts of Hurricane Sally?
# Answer:  Storm surge, heavy rain, and flash flooding
# True Answers: ['Flooding', 'Power outages', 'Structural damage']
# EM: 0 	 F1: 0
# Precision: 1.0 	 Recall: 0.14285714285714285
# Question:  What was the weather like in the days leading up to Hurricane Sally?
# Answer:  Hurricane Sally lumbered ashore near the Florida-Alabama line Wednesday with 105 mph (165) winds and rain measured in feet, not inches, swamping homes and trapping people in hig
# True Answers: ['Warm and humid']
# EM: 0 	 F1: 0.06666666666666667
# Precision: 0.3333333333333333 	 Recall: 0.037037037037037035
# Question:  What was the weather like in the days after Hurricane Sally?
# Answer:  Hurricane Sally lumbered ashore near the Florida-Alabama line Wednesday with 105 mph (165) winds and rain measured in feet, not inches, swamping homes and trapping people in hig Hurricane Sally’s threat: ‘Potentially historic’ floods
# True Answers: ['Cool and rainy']
# EM: 0 	 F1: 0.05555555555555555
# Precision: 0.3333333333333333 	 Recall: 0.030303030303030304
# Question:  What were the evacuation orders for Hurricane Sally?
# Answer:  a mandatory evacuation
# True Answers: ['Mandatory evacuations for some areas']
# EM: 0 	 F1: 0.28571428571428575
# Precision: 0.2 	 Recall: 0.5
# Question:  What were the shelter options for Hurricane Sally?
# Answer:  a shelter for livestock
# True Answers: ['Public shelters', 'Private shelters', 'Staying with friends or family']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What were the transportation options for Hurricane Sally?
# Answer:  a boat and high-water vehicles
# True Answers: ['Closed roads', 'Cancelled flights', 'Limited public transportation']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What were the communication options for Hurricane Sally?
# Answer:  a hurricane
# True Answers: ['Cell phone service was spotty', 'Power outages affected landlines', 'Radios were a good source of information']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Average Exact Match: 15.384615384615385 %
# Average F1 score: 0.20830280830280828
# Average Recall: 25.975875975875972 %
# Average Precision: 37.43589743589743 %

# %%
# Loop through all queries and perform evaluation
f1_scores = []
em_scores = []
recall_scores = []
precision_scores = []
for query in test_queries_facts:
    question = query['question']

    # Answer string (CHECK BY YASH) get output string
    predicted_answer = qa.run(question) 

    # Get gold answers
    gold_answers = get_gold_answers(query)

    # get EM score
    em_score = max((compute_exact_match(answer, predicted_answer)) for answer in gold_answers)
    # f1_score , prec, rec  = max((compute_f1(answer, predicted_answer)) for answer in gold_answers)
    
    # Get prec, rec and f1
    f1_list = []
    prec_list = []
    rec_list = []
    for answer in gold_answers:
        f1_score , prec, rec = compute_f1(answer, predicted_answer)
        f1_list.append(f1_score)
        prec_list.append(prec)
        rec_list.append(rec)

    print("Question: ", question)
    print("Answer: ", predicted_answer)
    print(f"True Answers: {gold_answers}")
    print(f"EM: {em_score} \t F1: {f1_score}")
    print(f"Precision: {max(prec_list)} \t Recall: {max(rec_list)}")

    em_scores.append(em_score)
    f1_scores.append(f1_score)
    recall_scores.append(max(rec_list))
    precision_scores.append(max(prec_list))

print(f"Average Exact Match: {(sum(em_scores) * 100 )/len(em_scores)} %")    
print(f"Average F1 score: {sum(f1_scores)/len(f1_scores)}")    
print(f"Average Recall: {(sum(recall_scores) * 100)/len(recall_scores)} %")    
print(f"Average Precision: {(sum(precision_scores) * 100) /len(precision_scores)} %")
# Out:
# Question:  How much rain is measured in Pensacola, Florida as of Tuesday?
# Answer:  b).
# True Answers: ['12.71 inches']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  Which areas are expecting heavy rain along I-10 highway from Louisiana to Florida,
# Answer:  Mobile Bay
# True Answers: [' Gautier and Pascagoula, Mississippi', 'Gautier', 'Pascagoula, Mississippi']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  What is the contact number to report downed power lines?
# Answer:  311
# True Answers: ['1-800-GUPOWER', '1-800-487-6937', '1-800-GUPOWER (1-800-487-6937)']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Question:  How many meal red cross has served?
# Answer:  622,000
# True Answers: ['622,000']
# EM: 1 	 F1: 1.0
# Precision: 1.0 	 Recall: 1.0
# Question:  What is the contact number of Alabama Power?
# Answer:  888-2726
# True Answers: ['1-800-888-2726']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Average Exact Match: 20.0 %
# Average F1 score: 0.2
# Average Recall: 20.0 %
# Average Precision: 20.0 %

# %%
def get_t5_answer(question,context):
    text_splitter = CharacterTextSplitter(chunk_size=20000, chunk_overlap=200,length_function = len)
    texts = text_splitter.split_text(context)
    embeddings = HuggingFaceEmbeddings()
    docsearch_new_t5 = Chroma.from_texts(texts, embeddings)
    qa_new_t5 = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch_new_t5.as_retriever(search_kwargs={"k": 1}))
    output_t5 = qa_new_t5.run(question)
    return output_t5

# %%
# Flan T5 Evaluation with Similarity Search same as Roberta and OpenAI.
f1_scores = []
em_scores = []
recall_scores = []
precision_scores = []
for query in test_queries:
    question = query['question']
    question_embeddings = sentence_model.encode([question])[0]

    context = get_question_context(question_embeddings)
    predicted_answer = get_t5_answer(question, context)

    # print("Context: ", context)
    print("Question: ", question)
    print("Answer: ", predicted_answer)

    gold_answers = get_gold_answers(query)

    em_score = max((compute_exact_match(answer, predicted_answer)) for answer in gold_answers)
    # f1_score , prec, rec  = max((compute_f1(answer, predicted_answer)) for answer in gold_answers)
    f1_list = []
    prec_list = []
    rec_list = []
    for answer in gold_answers:
        f1_score , prec, rec = compute_f1(answer, predicted_answer)
        f1_list.append(f1_score)
        prec_list.append(prec)
        rec_list.append(rec)

    # print(f"Question: {query['question']}")
    # print(f"Prediction: {predicted_answer}")
    print(f"True Answers: {gold_answers}")
    print(f"EM: {em_score} \t F1: {f1_score}")
    print(f"Precision: {max(prec_list)} \t Recall: {max(rec_list)}")

    em_scores.append(em_score)
    f1_scores.append(f1_score)
    recall_scores.append(max(rec_list))
    precision_scores.append(max(prec_list))

print(f"Average Exact Match: {(sum(em_scores) * 100 )/len(em_scores)} %")    
print(f"Average F1 score: {sum(f1_scores)/len(f1_scores)}")    
print(f"Average Recall: {(sum(recall_scores) * 100)/len(recall_scores)} %")    
print(f"Average Precision: {(sum(precision_scores) * 100) /len(precision_scores)} %")
# Out:
# Using embedded DuckDB without persistence: data will be transient
# Question:  What was the name of the hurricane that made landfall in Alabama and Mississippi on September 16, 2020?
# Answer:  Hurricane Sally
# True Answers: ['Hurricane Sally']
# EM: 1 	 F1: 1.0
# Precision: 1.0 	 Recall: 1.0
# Using embedded DuckDB without persistence: data will be transient
# Question:  What was the maximum sustained wind speed of Hurricane Sally when it made landfall?
# Answer:  35 mph
# True Answers: ['105 mph', '100 mph', '40 mph', '90 mph']
# EM: 0 	 F1: 0.5
# Precision: 0.5 	 Recall: 0.5
# Using embedded DuckDB without persistence: data will be transient
# Question:  Where did Hurricane Sally make landfall in Alabama?
# Answer:  Gulf Shores
# True Answers: ['Gulf Shores']
# EM: 1 	 F1: 1.0
# Precision: 1.0 	 Recall: 1.0
# Using embedded DuckDB without persistence: data will be transient
# Question:  Where did Hurricane Sally make landfall in Mississippi?
# Answer:  Alabama
# True Answers: ['Bay St. Louis']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Using embedded DuckDB without persistence: data will be transient
# Question:  What was the total damage caused by Hurricane Sally?
# Answer:  (iii)
# True Answers: ['More than $3 billion']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Using embedded DuckDB without persistence: data will be transient
# Question:  How many deaths were caused by Hurricane Sally?
# Answer:  1).
# True Answers: ['At least 3']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Using embedded DuckDB without persistence: data will be transient
# Question:  What were the main impacts of Hurricane Sally?
# Answer:  (iii)
# True Answers: ['Flooding', 'Power outages', 'Structural damage']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Using embedded DuckDB without persistence: data will be transient
# Question:  What was the weather like in the days leading up to Hurricane Sally?
# Answer:  Clear skies and cooler temperatures
# True Answers: ['Warm and humid']
# EM: 0 	 F1: 0.25
# Precision: 0.3333333333333333 	 Recall: 0.2
# Using embedded DuckDB without persistence: data will be transient
# Question:  What was the weather like in the days after Hurricane Sally?
# Answer:  Clear skies and cooler temperatures
# True Answers: ['Cool and rainy']
# EM: 0 	 F1: 0.25
# Precision: 0.3333333333333333 	 Recall: 0.2
# Using embedded DuckDB without persistence: data will be transient
# Question:  What were the evacuation orders for Hurricane Sally?
# Answer:  Counties issue evacuation orders, open shelters ahead of Hurricane Sally
# True Answers: ['Mandatory evacuations for some areas']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Using embedded DuckDB without persistence: data will be transient
# Question:  What were the shelter options for Hurricane Sally?
# Answer:  (iii)
# True Answers: ['Public shelters', 'Private shelters', 'Staying with friends or family']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Using embedded DuckDB without persistence: data will be transient
# Question:  What were the transportation options for Hurricane Sally?
# Answer:  Destin's charter boats
# True Answers: ['Closed roads', 'Cancelled flights', 'Limited public transportation']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Using embedded DuckDB without persistence: data will be transient
# Question:  What were the communication options for Hurricane Sally?
# Answer:  (iii)
# True Answers: ['Cell phone service was spotty', 'Power outages affected landlines', 'Radios were a good source of information']
# EM: 0 	 F1: 0
# Precision: 0 	 Recall: 0
# Average Exact Match: 15.384615384615385 %
# Average F1 score: 0.23076923076923078
# Average Recall: 22.307692307692314 %
# Average Precision: 24.35897435897436 %
